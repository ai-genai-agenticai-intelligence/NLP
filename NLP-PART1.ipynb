# %% [markdown]
# # NLU-[Natural Language Understanding]
# # import Libraries

# %%
import os
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# you can also create your own words
AI = '''Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of
humans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and
problem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.
It is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe
AI could solve major challenges and crisis situations.'''

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.'

# %%
type(AI)
# Out:
# str

# %% [markdown]
# # WordTokenize

# %%
from nltk.tokenize import word_tokenize

# %%
# what AI have here------------
#., also conider as tokenize
#Machine understand Word-------------------------
# hear symbol doesnot attached in text----------
AI_tokens = word_tokenize(AI)
AI_tokens
# Out:
# ['Artificial',
#  'Intelligence',
#  'refers',
#  'to',
#  'the',
#  'intelligence',
#  'of',
#  'machines',
#  '.',
#  'This',
#  'is',
#  'in',
#  'contrast',
#  'to',
#  'the',
#  'natural',
#  'intelligence',
#  'of',
#  'humans',
#  'and',
#  'animals',
#  '.',
#  'With',
#  'Artificial',
#  'Intelligence',
#  ',',
#  'machines',
#  'perform',
#  'functions',
#  'such',
#  'as',
#  'learning',
#  ',',
#  'planning',
#  ',',
#  'reasoning',
#  'and',
#  'problem-solving',
#  '.',
#  'Most',
#  'noteworthy',
#  ',',
#  'Artificial',
#  'Intelligence',
#  'is',
#  'the',
#  'simulation',
#  'of',
#  'human',
#  'intelligence',
#  'by',
#  'machines',
#  '.',
#  'It',
#  'is',
#  'probably',
#  'the',
#  'fastest-growing',
#  'development',
#  'in',
#  'the',
#  'World',
#  'of',
#  'technology',
#  'and',
#  'innovation',
#  '.',
#  'Furthermore',
#  ',',
#  'many',
#  'experts',
#  'believe',
#  'AI',
#  'could',
#  'solve',
#  'major',
#  'challenges',
#  'and',
#  'crisis',
# ...

# %%
len(AI_tokens)
# Out:
# 81

# %%
AI
# Out:
# 'Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.'

# %% [markdown]
# # SentanceTokenize

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokens = sent_tokenize(AI)
sent_tokens
# Out:
# ['Artificial Intelligence refers to the intelligence of machines.',
#  'This is in contrast to the natural intelligence of\nhumans and animals.',
#  'With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving.',
#  'Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.',
#  'It is probably the fastest-growing development in the World of technology and innovation.',
#  'Furthermore, many experts believe\nAI could solve major challenges and crisis situations.']

# %%
len(sent_tokens)
# Out:
# 6

# %% [markdown]
# # BlankineTokenize
# GIVE YOU HOW MANY PARAGRAPH

# %%
from nltk.tokenize import blankline_tokenize

# %%
AI_blank= blankline_tokenize(AI)
AI_blank
# Out:
# ['Artificial Intelligence refers to the intelligence of machines. This is in contrast to the natural intelligence of\nhumans and animals. With Artificial Intelligence, machines perform functions such as learning, planning, reasoning and\nproblem-solving. Most noteworthy, Artificial Intelligence is the simulation of human intelligence by machines.\nIt is probably the fastest-growing development in the World of technology and innovation. Furthermore, many experts believe\nAI could solve major challenges and crisis situations.']

# %%
len(AI_blank)
# Out:
# 1

# %% [markdown]
# # WhitespaceTokenize
# --- Symbols attached with text

# %%
from nltk.tokenize import WhitespaceTokenizer

# %%
wt =WhitespaceTokenizer().tokenize(AI)
wt
# Out:
# ['Artificial',
#  'Intelligence',
#  'refers',
#  'to',
#  'the',
#  'intelligence',
#  'of',
#  'machines.',
#  'This',
#  'is',
#  'in',
#  'contrast',
#  'to',
#  'the',
#  'natural',
#  'intelligence',
#  'of',
#  'humans',
#  'and',
#  'animals.',
#  'With',
#  'Artificial',
#  'Intelligence,',
#  'machines',
#  'perform',
#  'functions',
#  'such',
#  'as',
#  'learning,',
#  'planning,',
#  'reasoning',
#  'and',
#  'problem-solving.',
#  'Most',
#  'noteworthy,',
#  'Artificial',
#  'Intelligence',
#  'is',
#  'the',
#  'simulation',
#  'of',
#  'human',
#  'intelligence',
#  'by',
#  'machines.',
#  'It',
#  'is',
#  'probably',
#  'the',
#  'fastest-growing',
#  'development',
#  'in',
#  'the',
#  'World',
#  'of',
#  'technology',
#  'and',
#  'innovation.',
#  'Furthermore,',
#  'many',
#  'experts',
#  'believe',
#  'AI',
#  'could',
#  'solve',
#  'major',
#  'challenges',
#  'and',
#  'crisis',
#  'situations.']

# %% [markdown]
# # WORDPUNCTTokenize
# # Splits text into alphabetic and non-alphabetic characters
# # Separates punctuation, numbers, and symbols from words

# %%
s = 'Good apple cost $3.88 in hyderabad .Please buy two of them .Thanks.'
s
# Out:
# 'Good apple cost $3.88 in hyderabad .Please buy two of them .Thanks.'

# %%
from nltk.tokenize import wordpunct_tokenize
wordpunct_tokenize(s)
# Out:
# ['Good',
#  'apple',
#  'cost',
#  '$',
#  '3',
#  '.',
#  '88',
#  'in',
#  'hyderabad',
#  '.',
#  'Please',
#  'buy',
#  'two',
#  'of',
#  'them',
#  '.',
#  'Thanks',
#  '.']

# %%
w_p= wordpunct_tokenize(AI)
w_p
# Out:
# ['Artificial',
#  'Intelligence',
#  'refers',
#  'to',
#  'the',
#  'intelligence',
#  'of',
#  'machines',
#  '.',
#  'This',
#  'is',
#  'in',
#  'contrast',
#  'to',
#  'the',
#  'natural',
#  'intelligence',
#  'of',
#  'humans',
#  'and',
#  'animals',
#  '.',
#  'With',
#  'Artificial',
#  'Intelligence',
#  ',',
#  'machines',
#  'perform',
#  'functions',
#  'such',
#  'as',
#  'learning',
#  ',',
#  'planning',
#  ',',
#  'reasoning',
#  'and',
#  'problem',
#  '-',
#  'solving',
#  '.',
#  'Most',
#  'noteworthy',
#  ',',
#  'Artificial',
#  'Intelligence',
#  'is',
#  'the',
#  'simulation',
#  'of',
#  'human',
#  'intelligence',
#  'by',
#  'machines',
#  '.',
#  'It',
#  'is',
#  'probably',
#  'the',
#  'fastest',
#  '-',
#  'growing',
#  'development',
#  'in',
#  'the',
#  'World',
#  'of',
#  'technology',
#  'and',
#  'innovation',
#  '.',
#  'Furthermore',
#  ',',
#  'many',
#  'experts',
#  'believe',
#  'AI',
#  'could',
#  'solve',
#  'major',
# ...

# %%
len(w_p)
# Out:
# 85

# %%
len(wt)
# Out:
# 70

# %% [markdown]
# # Tokens devided into 3 parts--
# 1-bigrams
# 2-trigrams
# 3-ngramas

# %%
import nltk

# %%
from nltk.util import bigrams,trigrams,ngrams

# %%
string = 'generative ai & agentic ai is automate the industery &  more focous in domain'
string
# Out:
# 'generative ai & agentic ai is automate the industery &  more focous in domain'

# %%
qoutes_tokens =nltk.word_tokenize(string)
qoutes_tokens
# Out:
# ['generative',
#  'ai',
#  '&',
#  'agentic',
#  'ai',
#  'is',
#  'automate',
#  'the',
#  'industery',
#  '&',
#  'more',
#  'focous',
#  'in',
#  'domain']

# %%
len(qoutes_tokens)
# Out:
# 14

# %%
# tokens with 2 words
qoutes_tokens =list(nltk.bigrams(qoutes_tokens))
qoutes_tokens
# Out:
# [('generative', 'ai'),
#  ('ai', '&'),
#  ('&', 'agentic'),
#  ('agentic', 'ai'),
#  ('ai', 'is'),
#  ('is', 'automate'),
#  ('automate', 'the'),
#  ('the', 'industery'),
#  ('industery', '&'),
#  ('&', 'more'),
#  ('more', 'focous'),
#  ('focous', 'in'),
#  ('in', 'domain')]

# %%
# tokens with 3 words
qoutes_tokens =list(nltk.trigrams(qoutes_tokens))
qoutes_tokens
# Out:
# [(('generative', 'ai'), ('ai', '&'), ('&', 'agentic')),
#  (('ai', '&'), ('&', 'agentic'), ('agentic', 'ai')),
#  (('&', 'agentic'), ('agentic', 'ai'), ('ai', 'is')),
#  (('agentic', 'ai'), ('ai', 'is'), ('is', 'automate')),
#  (('ai', 'is'), ('is', 'automate'), ('automate', 'the')),
#  (('is', 'automate'), ('automate', 'the'), ('the', 'industery')),
#  (('automate', 'the'), ('the', 'industery'), ('industery', '&')),
#  (('the', 'industery'), ('industery', '&'), ('&', 'more')),
#  (('industery', '&'), ('&', 'more'), ('more', 'focous')),
#  (('&', 'more'), ('more', 'focous'), ('focous', 'in')),
#  (('more', 'focous'), ('focous', 'in'), ('in', 'domain'))]

# %%
# token with more words
qoutes_tokens =list(nltk.ngrams(qoutes_tokens,4))
qoutes_tokens
# Out:
# [((('generative', 'ai'), ('ai', '&'), ('&', 'agentic')),
#   (('ai', '&'), ('&', 'agentic'), ('agentic', 'ai')),
#   (('&', 'agentic'), ('agentic', 'ai'), ('ai', 'is')),
#   (('agentic', 'ai'), ('ai', 'is'), ('is', 'automate'))),
#  ((('ai', '&'), ('&', 'agentic'), ('agentic', 'ai')),
#   (('&', 'agentic'), ('agentic', 'ai'), ('ai', 'is')),
#   (('agentic', 'ai'), ('ai', 'is'), ('is', 'automate')),
#   (('ai', 'is'), ('is', 'automate'), ('automate', 'the'))),
#  ((('&', 'agentic'), ('agentic', 'ai'), ('ai', 'is')),
#   (('agentic', 'ai'), ('ai', 'is'), ('is', 'automate')),
#   (('ai', 'is'), ('is', 'automate'), ('automate', 'the')),
#   (('is', 'automate'), ('automate', 'the'), ('the', 'industery'))),
#  ((('agentic', 'ai'), ('ai', 'is'), ('is', 'automate')),
#   (('ai', 'is'), ('is', 'automate'), ('automate', 'the')),
#   (('is', 'automate'), ('automate', 'the'), ('the', 'industery')),
#   (('automate', 'the'), ('the', 'industery'), ('industery', '&'))),
# ...

# %% [markdown]
# # STEMMING
# # 1-Suffix-A suffix is a group of letters added to the end of a word to change its meaning or form.
# # 2-Perfix-A prefix is a group of letters added to the beginning of a word to change its meaning.
# # 3- it give root from of the word

# %%
from nltk.stem import PorterStemmer
pst =PorterStemmer()

# %%
pst.stem('affection')
# Out:
# 'affect'

# %%
pst.stem('playing')
# Out:
# 'play'

# %%
pst.stem('maximum')
# Out:
# 'maximum'

# %%
words_to_stem =['give','giving','given','gave','thinking','loving','maximum']

for word in words_to_stem:
    print(word +':' + pst.stem(word))
# Out:
# give:give
# giving:give
# given:given
# gave:gave
# thinking:think
# loving:love
# maximum:maximum

# %%
from nltk.stem import LancasterStemmer

for word in words_to_stem:
    print(word +':'+pst.stem(word))
# Out:
# give:give
# giving:give
# given:given
# gave:gave
# thinking:think
# loving:love
# maximum:maximum

# %%
from nltk.stem import SnowballStemmer
lst = SnowballStemmer

for word in words_to_stem:
    print(word +':'+pst.stem(word))
# Out:
# give:give
# giving:give
# given:given
# gave:gave
# thinking:think
# loving:love
# maximum:maximum

# %%
stemmer =SnowballStemmer('german')
stemmer.stem('Autobahnen')
# Out:
# 'autobahn'

# %% [markdown]
# # LEMMATIZATION
# # it will givw a complete word

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer
word_lem =WordNetLemmatizer()

# %%
for word in words_to_stem:
    print(word +':' +word_lem.lemmatize(word))
# Out:
# give:give
# giving:giving
# given:given
# gave:gave
# thinking:thinking
# loving:loving
# maximum:maximum

# %% [markdown]
# # Stops Words in NLP
# # 1- Common words which speaks everytime
# # 2- we need to remove stopwords to reduce model size
#
# # 3- remove stopwords(like--- "a", "an", "the", "in", "on", "at", "and", "but", "or", "is", "was", "are") reduce dataset size

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
len(stopwords.words('english'))
# Out:
# 198

# %%
stopwords.words('french')
# Out:
# ['au',
#  'aux',
#  'avec',
#  'ce',
#  'ces',
#  'dans',
#  'de',
#  'des',
#  'du',
#  'elle',
#  'en',
#  'et',
#  'eux',
#  'il',
#  'ils',
#  'je',
#  'la',
#  'le',
#  'les',
#  'leur',
#  'lui',
#  'ma',
#  'mais',
#  'me',
#  'même',
#  'mes',
#  'moi',
#  'mon',
#  'ne',
#  'nos',
#  'notre',
#  'nous',
#  'on',
#  'ou',
#  'par',
#  'pas',
#  'pour',
#  'qu',
#  'que',
#  'qui',
#  'sa',
#  'se',
#  'ses',
#  'son',
#  'sur',
#  'ta',
#  'te',
#  'tes',
#  'toi',
#  'ton',
#  'tu',
#  'un',
#  'une',
#  'vos',
#  'votre',
#  'vous',
#  'c',
#  'd',
#  'j',
#  'l',
#  'à',
#  'm',
#  'n',
#  's',
#  't',
#  'y',
#  'été',
#  'étée',
#  'étées',
#  'étés',
#  'étant',
#  'étante',
#  'étants',
#  'étantes',
#  'suis',
#  'es',
#  'est',
#  'sommes',
#  'êtes',
#  'sont',
#  'serai',
#  'seras',
#  'sera',
#  'serons',
#  'serez',
#  'seront',
#  'serais',
#  'serait',
#  'serions',
#  'seriez',
#  'seraient',
#  'étais',
#  'était',
#  'étions',
#  'étiez',
#  'étaient',
# ...

# %%
len(stopwords.words('german'))
# Out:
# 232

# %%
stopwords.words('chinese')
# Out:
# ['一',
#  '一下',
#  '一些',
#  '一切',
#  '一则',
#  '一天',
#  '一定',
#  '一方面',
#  '一旦',
#  '一时',
#  '一来',
#  '一样',
#  '一次',
#  '一片',
#  '一直',
#  '一致',
#  '一般',
#  '一起',
#  '一边',
#  '一面',
#  '万一',
#  '上下',
#  '上升',
#  '上去',
#  '上来',
#  '上述',
#  '上面',
#  '下列',
#  '下去',
#  '下来',
#  '下面',
#  '不一',
#  '不久',
#  '不仅',
#  '不会',
#  '不但',
#  '不光',
#  '不单',
#  '不变',
#  '不只',
#  '不可',
#  '不同',
#  '不够',
#  '不如',
#  '不得',
#  '不怕',
#  '不惟',
#  '不成',
#  '不拘',
#  '不敢',
#  '不断',
#  '不是',
#  '不比',
#  '不然',
#  '不特',
#  '不独',
#  '不管',
#  '不能',
#  '不要',
#  '不论',
#  '不足',
#  '不过',
#  '不问',
#  '与',
#  '与其',
#  '与否',
#  '与此同时',
#  '专门',
#  '且',
#  '两者',
#  '严格',
#  '严重',
#  '个',
#  '个人',
#  '个别',
#  '中小',
#  '中间',
#  '丰富',
#  '临',
#  '为',
#  '为主',
#  '为了',
#  '为什么',
#  '为什麽',
#  '为何',
#  '为着',
#  '主张',
#  '主要',
#  '举行',
#  '乃',
#  '乃至',
#  '么',
#  '之',
#  '之一',
#  '之前',
#  '之后',
#  '之後',
#  '之所以',
#  '之类',
#  '乌乎',
#  '乎',
#  '乘',
#  '也',
#  '也好',
#  '也是',
#  '也罢',
#  '了',
#  '了解',
#  '争取',
#  '于',
#  '于是',
# ...

# %%
len(stopwords.words('chinese'))
# Out:
# 841

# %%
stopwords.words('Bengali')
# Out:
# ['অতএব',
#  'অথচ',
#  'অথবা',
#  'অনুযায়ী',
#  'অনেক',
#  'অনেকে',
#  'অনেকেই',
#  'অন্তত',
#  'অন্য',
#  'অবধি',
#  'অবশ্য',
#  'অর্থাত',
#  'আই',
#  'আগামী',
#  'আগে',
#  'আগেই',
#  'আছে',
#  'আজ',
#  'আদ্যভাগে',
#  'আপনার',
#  'আপনি',
#  'আবার',
#  'আমরা',
#  'আমাকে',
#  'আমাদের',
#  'আমার',
#  'আমি',
#  'আর',
#  'আরও',
#  'ই',
#  'ইত্যাদি',
#  'ইহা',
#  'উচিত',
#  'উত্তর',
#  'উনি',
#  'উপর',
#  'উপরে',
#  'এ',
#  'এঁদের',
#  'এঁরা',
#  'এই',
#  'একই',
#  'একটি',
#  'একবার',
#  'একে',
#  'এক্',
#  'এখন',
#  'এখনও',
#  'এখানে',
#  'এখানেই',
#  'এটা',
#  'এটাই',
#  'এটি',
#  'এত',
#  'এতটাই',
#  'এতে',
#  'এদের',
#  'এব',
#  'এবং',
#  'এবার',
#  'এমন',
#  'এমনকী',
#  'এমনি',
#  'এর',
#  'এরা',
#  'এল',
#  'এস',
#  'এসে',
#  'ঐ',
#  'ও',
#  'ওঁদের',
#  'ওঁর',
#  'ওঁরা',
#  'ওই',
#  'ওকে',
#  'ওখানে',
#  'ওদের',
#  'ওর',
#  'ওরা',
#  'কখনও',
#  'কত',
#  'কবে',
#  'কমনে',
#  'কয়েক',
#  'কয়েকটি',
#  'করছে',
#  'করছেন',
#  'করতে',
#  'করবে',
#  'করবেন',
#  'করলে',
#  'করলেন',
# ...

# %%
len(stopwords.words('Bengali'))
# Out:
# 398

# %% [markdown]
# # CONTEXTWINDOW
# # 1- every LLM has a context window
# # 2- A context window measure tokens not words

# %% [markdown]
# # POS :Parts of Speech
# ---------------------------------------
# # 1-this machine how the recognize  the grammer information)

# %%
sent ='my name is abhishek sahoo'
sent_tokens =word_tokenize(sent)
sent_tokens
# Out:
# ['my', 'name', 'is', 'abhishek', 'sahoo']

# %%
for token in sent_tokens:
    print(nltk.pos_tag([token]))
# Out:
# [('my', 'PRP$')]
# [('name', 'NN')]
# [('is', 'VBZ')]
# [('abhishek', 'NN')]
# [('sahoo', 'NN')]

# %% [markdown]
# # NER (Named Entity Recognization)

# %%
from nltk import ne_chunk

# %%
NE_sent ='This US president stays in the WHITESPACE'

# %%
NE_tokens =word_tokenize(NE_sent)
NE_tokens
# Out:
# ['This', 'US', 'president', 'stays', 'in', 'the', 'WHITESPACE']

# %%
# it is recognize the grammer
NE_tags =nltk.pos_tag(NE_tokens)
NE_tags
# Out:
# [('This', 'DT'),
#  ('US', 'NNP'),
#  ('president', 'NN'),
#  ('stays', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('WHITESPACE', 'NNP')]

# %%
NE_NER = ne_chunk(NE_tags)
print(NE_NER)
# Out:
# (S
#   This/DT
#   (GPE US/NNP)
#   president/NN
#   stays/NNS
#   in/IN
#   the/DT
#   (ORGANIZATION WHITESPACE/NNP))

# %% [markdown]
# # NLG-[Natural Language Generation]

# %%
! pip install wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
text =text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")
text
# Out:
# 'Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble'

# %% [markdown]
# # Create the wordcloud object
# # WordCloud---what is more highlighted word/Big that we called WordCloud

# %%
wordcloud = WordCloud(
    width=420,
    height=200,
    margin=2,
    background_color='black',
    colormap='Accent',
    mode='RGB'
).generate(text)

# %%
# Display the generate image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# # NLP-Algorthim
# -Emabadding Concept--means it is converted to vector(0,1,0,1,1)
# # 1- convert word to vector
# # NLP ALgorthim mainly devided into 3 part-
# # 1-Bag of word
# # 2-TF*IDF-(term frequency *inverse document frequency)
# # 3-word2vec
# # bag of words (word embadding)

# %%
from sklearn.feature_extraction.text import CountVectorizer

sentence = 'data science ai genai as has great career ahead data science data'
vectorizer = CountVectorizer()
vector = vectorizer.fit_transform([sentence])
print(vector.toarray())
# Out:
# [[1 1 1 1 3 1 1 1 2]]

# %% [markdown]
# # TFIDF --- term frequency and inverse document frequency

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

sentence = 'data science ai genai as has great career ahead data science data'
vectorizer = CountVectorizer()
vector = vectorizer.fit_transform([sentence])
print(vector.toarray())
# Out:
# [[1 1 1 1 3 1 1 1 2]]

# %% [markdown]
# # CHUNKING---
# #  Split entire area into small para(chunk) pice of sentence(chunk)
# # CHUNKING are devided into 3 parts--
# # 1-Noun Phrases
# # 2-Verb Phases
# # 3-Preposition Phases

# %%
import nltk
from nltk import pos_tag, word_tokenize, RegexpParser #RegularExpression Parser 

# Download necessary NLTK data files (only need to do this once)
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# Sample text
text = "full stack datasceince, generative ai, agenti ai, llm model keep increase by different compnay"

# Tokenize the text
tokens = word_tokenize(text)

# Perform part-of-speech tagging
tagged_tokens = pos_tag(tokens)

# Define a chunk grammar
chunk_grammar = r"""
  NP: {<DT>?<JJ>*<NN>}   # Noun Phrase
  VP: {<VB.*><NP|PP>*}    # Verb Phrase
  PP: {<IN><NP>}          # Prepositional Phrase
"""

# Create a chunk parser
chunk_parser = RegexpParser(chunk_grammar)

# Parse the tagged tokens
chunked = chunk_parser.parse(tagged_tokens)

# Print the chunked output
print(chunked)

# Optionally, you can visualize the chunks
chunked.draw()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\abhis\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# (S
#   (NP full/JJ stack/NN)
#   (NP datasceince/NN)
#   ,/,
#   (NP generative/JJ ai/NN)
#   ,/,
#   (NP agenti/NN)
#   (NP ai/NN)
#   ,/,
#   (NP llm/JJ model/NN)
#   (VP keep/VB (NP increase/NN))
#   (PP by/IN (NP different/JJ compnay/NN)))
