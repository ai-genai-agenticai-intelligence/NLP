# %%
! pip install spacy
# Out:
# Requirement already satisfied: spacy in C:\Users\abhis\anaconda3\Lib\site-packages (3.8.14)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (0.17.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (2.3.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (2.32.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (2.12.4)
# Requirement already satisfied: jinja2 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (82.0.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from spacy) (25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\abhis\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\abhis\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\abhis\anaconda3\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\abhis\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\abhis\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\abhis\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\abhis\anaconda3\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.1.4)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: colorama in C:\Users\abhis\anaconda3\Lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.2.0)
# Requirement already satisfied: cloudpathlib>=0.7.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.23.0)
# Requirement already satisfied: smart-open>=5.2.1 in C:\Users\abhis\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (7.5.1)
# Requirement already satisfied: httpx>=0.24.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: anyio in C:\Users\abhis\anaconda3\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.10.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\abhis\anaconda3\Lib\site-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\abhis\anaconda3\Lib\site-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\abhis\anaconda3\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: wrapt in C:\Users\abhis\anaconda3\Lib\site-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\abhis\anaconda3\Lib\site-packages (from anyio->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\abhis\anaconda3\Lib\site-packages (from jinja2->spacy) (3.0.2)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl
#      - 0 bytes ? 0:00:00
#      - 0 bytes ? 0:00:00
# ERROR: Wheel 'en-core-web-sm' located at C:\Users\abhis\AppData\Local\Temp\pip-unpack-2s7wd6_0\en_core_web_sm-3.8.0-py3-none-any.whl is invalid.

# %%
import spacy
nlp =spacy.load('en_core_web_sm')
doc =nlp('data science and ai & gen ai has great career ahead')

# %%
doc
# Out:
# data science and ai & gen ai has great career ahead

# %%
for token  in doc:
    print(token.text)
# Out:
# data
# science
# and
# ai
# &
# gen
# ai
# has
# great
# career
# ahead

# %%
for token in doc:
    print(token.text,':',token.pos_)
# Out:
# data : NOUN
# science : NOUN
# and : CCONJ
# ai : PROPN
# & : CCONJ
# gen : PROPN
# ai : PROPN
# has : VERB
# great : ADJ
# career : NOUN
# ahead : ADV

# %%
for token in doc:
    print(token.text,token.lemma_,token.pos_,
          token.tag_,token.dep_,token.shape_,token.is_alpha,token.is_stop)
# Out:
# data data NOUN NN compound xxxx True False
# science science NOUN NN nsubj xxxx True False
# and and CCONJ CC cc xxx True True
# ai ai PROPN NNP conj xx True False
# & & CCONJ CC cc & False False
# gen gen PROPN NNP conj xxx True False
# ai ai PROPN NNP conj xx True False
# has have VERB VBZ ROOT xxx True True
# great great ADJ JJ amod xxxx True False
# career career NOUN NN dobj xxxx True False
# ahead ahead ADV RB advmod xxxx True False

# %%
for token in doc:
    print(token.pos_)
# Out:
# NOUN
# NOUN
# CCONJ
# PROPN
# CCONJ
# PROPN
# PROPN
# VERB
# ADJ
# NOUN
# ADV

# %%
for token in doc:
    print(token.text,':',token.pos_)
# Out:
# data : NOUN
# science : NOUN
# and : CCONJ
# ai : PROPN
# & : CCONJ
# gen : PROPN
# ai : PROPN
# has : VERB
# great : ADJ
# career : NOUN
# ahead : ADV

# %%
for token in doc:
    print(token.text,token.pos_,token.lemma_)
# Out:
# data NOUN data
# science NOUN science
# and CCONJ and
# ai PROPN ai
# & CCONJ &
# gen PROPN gen
# ai PROPN ai
# has VERB have
# great ADJ great
# career NOUN career
# ahead ADV ahead

# %%
text='However, there are a few glitches, which may not be deal-breakers per say but do stick out. For instance, Tamannaah, who plays the Katniss Everdeen like bow-wielding warrior, breaks into a romantic song with Shiva, baring her slender midriff to cater to ‘popular demands’. Shiva’s impromptu dance under the waterfall is reminiscent of a Liril commercial. The film’s duration could be an issue for those not high on patience. Also, the movie reminds you of Troy, Thor, The Dark Knight Rises, Karan Arjun (Devasena chanting, ‘Mera beta aayega’) to name a few, giving you the recurring ‘been-there-seen-that’ feeling. Shiva has the values of Prince Hector, bravery of Achilles and can make the jump Bruce Wayne did to get out of the pit. Bhallala deva can be Agamemnon.However, the elaborate battle-scene climax makes the film a spectacular watch nonetheless. Very rarely has an Indian film managed to achieve this feat. The casting is terrific. Ramya Krishnan in her short but substantial role is flawless as the feisty Raajmata. Tamannaah does the action bit well. Prabhas and Rana Daggubati are outstanding. They hugely contribute to making this routine good vs bad film a visual extravaganza…entertainment guaranteed. The scene which sees Shiva singlehandedly erecting a giant gold statue of Bhallala Deva is jawdroppingly iconic. Take a bow S.S. Rajamouli.'

# %%
text
# Out:
# 'However, there are a few glitches, which may not be deal-breakers per say but do stick out. For instance, Tamannaah, who plays the Katniss Everdeen like bow-wielding warrior, breaks into a romantic song with Shiva, baring her slender midriff to cater to ‘popular demands’. Shiva’s impromptu dance under the waterfall is reminiscent of a Liril commercial. The film’s duration could be an issue for those not high on patience. Also, the movie reminds you of Troy, Thor, The Dark Knight Rises, Karan Arjun (Devasena chanting, ‘Mera beta aayega’) to name a few, giving you the recurring ‘been-there-seen-that’ feeling. Shiva has the values of Prince Hector, bravery of Achilles and can make the jump Bruce Wayne did to get out of the pit. Bhallala deva can be Agamemnon.However, the elaborate battle-scene climax makes the film a spectacular watch nonetheless. Very rarely has an Indian film managed to achieve this feat. The casting is terrific. Ramya Krishnan in her short but substantial role is flawless as the feisty Raajmata. Tamannaah does the action bit well. Prabhas and Rana Daggubati are outstanding. They hugely contribute to making this routine good vs bad film a visual extravaganza…entertainment guaranteed. The scene which sees Shiva singlehandedly erecting a giant gold statue of Bhallala Deva is jawdroppingly iconic. Take a bow S.S. Rajamouli.'

# %%
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
stopwords =list(STOP_WORDS)
stopwords
# Out:
# ['via',
#  '‘s',
#  'the',
#  'become',
#  'amongst',
#  'hers',
#  'if',
#  'those',
#  'among',
#  'because',
#  'whenever',
#  'call',
#  'itself',
#  'hundred',
#  'except',
#  'next',
#  'between',
#  'or',
#  'twenty',
#  "'s",
#  'full',
#  'now',
#  'eleven',
#  'whereupon',
#  'besides',
#  '‘m',
#  'can',
#  'should',
#  'former',
#  'did',
#  'hence',
#  'otherwise',
#  'give',
#  'yourself',
#  'made',
#  'hereupon',
#  'we',
#  'namely',
#  'none',
#  '’s',
#  'eight',
#  'and',
#  'further',
#  're',
#  'anywhere',
#  'he',
#  'per',
#  'back',
#  'could',
#  'sometimes',
#  'she',
#  'almost',
#  'hereby',
#  'above',
#  'i',
#  'is',
#  'there',
#  'will',
#  'you',
#  'serious',
#  'had',
#  'might',
#  'themselves',
#  'why',
#  'latter',
#  'would',
#  'seem',
#  'other',
#  'wherein',
#  'either',
#  'thence',
#  'behind',
#  'thus',
#  'since',
#  'meanwhile',
#  'been',
#  'forty',
#  'only',
#  '’m',
#  'around',
#  'herself',
#  'to',
#  'off',
#  'their',
#  'without',
#  'again',
#  'done',
#  'nothing',
#  'no',
#  'than',
#  'part',
#  'noone',
#  'alone',
#  'same',
#  '’ll',
#  'much',
#  'whole',
#  'say',
#  'us',
#  'thereby',
#  'more',
#  "'d",
#  "'ll",
#  'everywhere',
#  '’ve',
#  'becomes',
#  'they',
#  'everyone',
#  'a',
#  'move',
#  'also',
#  'all',
#  'beside',
#  'regarding',
#  'across',
#  'sixty',
#  'n’t',
#  'formerly',
#  'nor',
#  'at',
#  'take',
#  'mine',
#  'someone',
#  'in',
#  'keep',
#  'became',
#  'are',
#  'along',
#  'still',
#  'together',
#  'various',
#  'one',
#  'put',
#  'not',
#  'be',
#  'on',
#  'five',
#  'something',
#  'latterly',
#  'third',
#  'neither',
#  'make',
#  'sometime',
#  'top',
#  'whose',
#  'whence',
#  'cannot',
#  'whither',
#  '‘ve',
#  'for',
#  'which',
#  'even',
#  'toward',
#  'down',
#  "'ve",
#  'herein',
#  'front',
#  'fifty',
#  'moreover',
#  'show',
#  'quite',
#  'used',
#  'indeed',
#  'whereas',
#  'becoming',
#  'seems',
#  'most',
#  'out',
#  'from',
#  'have',
#  'empty',
#  'ten',
#  'each',
#  'his',
#  '‘ll',
#  'last',
#  'due',
#  "n't",
#  'its',
#  'that',
#  '‘d',
#  'never',
#  'beyond',
#  'whether',
#  'six',
#  'her',
#  'first',
#  'an',
#  'here',
#  'yours',
#  'were',
#  'my',
#  'where',
#  'very',
#  'but',
#  'when',
#  '’re',
#  'into',
#  'less',
#  'else',
#  'yourselves',
#  'am',
#  "'re",
#  'ourselves',
#  'both',
#  'wherever',
#  'such',
#  'too',
#  'really',
#  'go',
#  'as',
#  'some',
#  'up',
#  'me',
#  'once',
#  'being',
#  'do',
#  'four',
#  'anything',
#  'another',
#  'though',
#  'unless',
#  'yet',
#  'get',
#  'nevertheless',
#  'throughout',
#  'how',
#  'our',
#  '’d',
#  'many',
#  'anyway',
#  'nine',
#  'hereafter',
#  'nowhere',
#  'rather',
#  'him',
#  'afterwards',
#  'myself',
#  'anyone',
#  'ever',
#  'nobody',
#  'these',
#  'who',
#  'of',
#  'few',
#  'towards',
#  'using',
#  'any',
#  'see',
#  'elsewhere',
#  'them',
#  'thru',
#  'amount',
#  'so',
#  'before',
#  'ours',
#  'somehow',
#  'therein',
#  'thereafter',
#  'upon',
#  'then',
#  'what',
#  'against',
#  'by',
#  'whom',
#  'whereafter',
#  'himself',
#  'seeming',
#  'anyhow',
#  'perhaps',
#  'please',
#  'does',
#  'thereupon',
#  'although',
#  'must',
#  'within',
#  'others',
#  'two',
#  'several',
#  'after',
#  'over',
#  'with',
#  'seemed',
#  'often',
#  'was',
#  'fifteen',
#  'n‘t',
#  'bottom',
#  'mostly',
#  '‘re',
#  'it',
#  'however',
#  'until',
#  'every',
#  'about',
#  'already',
#  'through',
#  'under',
#  'always',
#  'three',
#  'this',
#  'whereby',
#  'side',
#  'whatever',
#  'while',
#  'may',
#  'twelve',
#  'therefore',
#  'name',
#  'ca',
#  'during',
#  'your',
#  'enough',
#  'below',
#  'well',
#  "'m",
#  'onto',
#  'doing',
#  'beforehand',
#  'whoever',
#  'least',
#  'has',
#  'just',
#  'own',
#  'everything',
#  'somewhere']

# %%
len(stopwords)
# Out:
# 326

# %%
nlp =spacy.load('en_core_web_sm')

# %%
doc =nlp(text)
doc
# Out:
# However, there are a few glitches, which may not be deal-breakers per say but do stick out. For instance, Tamannaah, who plays the Katniss Everdeen like bow-wielding warrior, breaks into a romantic song with Shiva, baring her slender midriff to cater to ‘popular demands’. Shiva’s impromptu dance under the waterfall is reminiscent of a Liril commercial. The film’s duration could be an issue for those not high on patience. Also, the movie reminds you of Troy, Thor, The Dark Knight Rises, Karan Arjun (Devasena chanting, ‘Mera beta aayega’) to name a few, giving you the recurring ‘been-there-seen-that’ feeling. Shiva has the values of Prince Hector, bravery of Achilles and can make the jump Bruce Wayne did to get out of the pit. Bhallala deva can be Agamemnon.However, the elaborate battle-scene climax makes the film a spectacular watch nonetheless. Very rarely has an Indian film managed to achieve this feat. The casting is terrific. Ramya Krishnan in her short but substantial role is flawless as the feisty Raajmata. Tamannaah does the action bit well. Prabhas and Rana Daggubati are outstanding. They hugely contribute to making this routine good vs bad film a visual extravaganza…entertainment guaranteed. The scene which sees Shiva singlehandedly erecting a giant gold statue of Bhallala Deva is jawdroppingly iconic. Take a bow S.S. Rajamouli.

# %%
for token in doc:
    print(token.text)
# Out:
# However
# ,
# there
# are
# a
# few
# glitches
# ,
# which
# may
# not
# be
# deal
# -
# breakers
# per
# say
# but
# do
# stick
# out
# .
# For
# instance
# ,
# Tamannaah
# ,
# who
# plays
# the
# Katniss
# Everdeen
# like
# bow
# -
# wielding
# warrior
# ,
# breaks
# into
# a
# romantic
# song
# with
# Shiva
# ,
# baring
# her
# slender
# midriff
# to
# cater
# to
# ‘
# popular
# demands
# ’
# .
# Shiva
# ’s
# impromptu
# dance
# under
# the
# waterfall
# is
# reminiscent
# of
# a
# Liril
# commercial
# .
# The
# film
# ’s
# duration
# could
# be
# an
# issue
# for
# those
# not
# high
# on
# patience
# .
# Also
# ,
# the
# movie
# reminds
# you
# of
# Troy
# ,
# Thor
# ,
# The
# Dark
# Knight
# Rises
# ,
# Karan
# Arjun
# (
# Devasena
# chanting
# ,
# ‘
# Mera
# beta
# aayega
# ’
# )
# to
# name
# a
# few
# ,
# giving
# you
# the
# recurring
# ‘
# been
# -
# there
# -
# seen
# -
# that
# ’
# feeling
# .
# Shiva
# has
# the
# values
# of
# Prince
# Hector
# ,
# bravery
# of
# Achilles
# and
# can
# make
# the
# jump
# Bruce
# Wayne
# did
# to
# get
# out
# of
# the
# pit
# .
# Bhallala
# deva
# can
# be
# Agamemnon
# .
# However
# ,
# the
# elaborate
# battle
# -
# scene
# climax
# makes
# the
# film
# a
# spectacular
# watch
# nonetheless
# .
# Very
# rarely
# has
# an
# Indian
# film
# managed
# to
# achieve
# this
# feat
# .
# The
# casting
# is
# terrific
# .
# Ramya
# Krishnan
# in
# her
# short
# but
# substantial
# role
# is
# flawless
# as
# the
# feisty
# Raajmata
# .
# Tamannaah
# does
# the
# action
# bit
# well
# .
# Prabhas
# and
# Rana
# Daggubati
# are
# outstanding
# .
# They
# hugely
# contribute
# to
# making
# this
# routine
# good
# vs
# bad
# film
# a
# visual
# extravaganza
# …
# entertainment
# guaranteed
# .
# The
# scene
# which
# sees
# Shiva
# singlehandedly
# erecting
# a
# giant
# gold
# statue
# of
# Bhallala
# Deva
# is
# jawdroppingly
# iconic
# .
# Take
# a
# bow
# S.S.
# Rajamouli
# .

# %%
len(text)
# Out:
# 1358

# %%
tokens=[token.text for token in doc]
#print(tokens)
tokens
# Out:
# ['However',
#  ',',
#  'there',
#  'are',
#  'a',
#  'few',
#  'glitches',
#  ',',
#  'which',
#  'may',
#  'not',
#  'be',
#  'deal',
#  '-',
#  'breakers',
#  'per',
#  'say',
#  'but',
#  'do',
#  'stick',
#  'out',
#  '.',
#  'For',
#  'instance',
#  ',',
#  'Tamannaah',
#  ',',
#  'who',
#  'plays',
#  'the',
#  'Katniss',
#  'Everdeen',
#  'like',
#  'bow',
#  '-',
#  'wielding',
#  'warrior',
#  ',',
#  'breaks',
#  'into',
#  'a',
#  'romantic',
#  'song',
#  'with',
#  'Shiva',
#  ',',
#  'baring',
#  'her',
#  'slender',
#  'midriff',
#  'to',
#  'cater',
#  'to',
#  '‘',
#  'popular',
#  'demands',
#  '’',
#  '.',
#  'Shiva',
#  '’s',
#  'impromptu',
#  'dance',
#  'under',
#  'the',
#  'waterfall',
#  'is',
#  'reminiscent',
#  'of',
#  'a',
#  'Liril',
#  'commercial',
#  '.',
#  'The',
#  'film',
#  '’s',
#  'duration',
#  'could',
#  'be',
#  'an',
#  'issue',
#  'for',
#  'those',
#  'not',
#  'high',
#  'on',
#  'patience',
#  '.',
#  'Also',
#  ',',
#  'the',
#  'movie',
#  'reminds',
#  'you',
#  'of',
#  'Troy',
#  ',',
#  'Thor',
#  ',',
#  'The',
#  'Dark',
#  'Knight',
#  'Rises',
#  ',',
#  'Karan',
#  'Arjun',
#  '(',
#  'Devasena',
#  'chanting',
#  ',',
#  '‘',
#  'Mera',
#  'beta',
#  'aayega',
#  '’',
#  ')',
#  'to',
#  'name',
#  'a',
#  'few',
#  ',',
#  'giving',
#  'you',
#  'the',
#  'recurring',
#  '‘',
#  'been',
#  '-',
#  'there',
#  '-',
#  'seen',
#  '-',
#  'that',
#  '’',
#  'feeling',
#  '.',
#  'Shiva',
#  'has',
#  'the',
#  'values',
#  'of',
#  'Prince',
#  'Hector',
#  ',',
#  'bravery',
#  'of',
#  'Achilles',
#  'and',
#  'can',
#  'make',
#  'the',
#  'jump',
#  'Bruce',
#  'Wayne',
#  'did',
#  'to',
#  'get',
#  'out',
#  'of',
#  'the',
#  'pit',
#  '.',
#  'Bhallala',
#  'deva',
#  'can',
#  'be',
#  'Agamemnon',
#  '.',
#  'However',
#  ',',
#  'the',
#  'elaborate',
#  'battle',
#  '-',
#  'scene',
#  'climax',
#  'makes',
#  'the',
#  'film',
#  'a',
#  'spectacular',
#  'watch',
#  'nonetheless',
#  '.',
#  'Very',
#  'rarely',
#  'has',
#  'an',
#  'Indian',
#  'film',
#  'managed',
#  'to',
#  'achieve',
#  'this',
#  'feat',
#  '.',
#  'The',
#  'casting',
#  'is',
#  'terrific',
#  '.',
#  'Ramya',
#  'Krishnan',
#  'in',
#  'her',
#  'short',
#  'but',
#  'substantial',
#  'role',
#  'is',
#  'flawless',
#  'as',
#  'the',
#  'feisty',
#  'Raajmata',
#  '.',
#  'Tamannaah',
#  'does',
#  'the',
#  'action',
#  'bit',
#  'well',
#  '.',
#  'Prabhas',
#  'and',
#  'Rana',
#  'Daggubati',
#  'are',
#  'outstanding',
#  '.',
#  'They',
#  'hugely',
#  'contribute',
#  'to',
#  'making',
#  'this',
#  'routine',
#  'good',
#  'vs',
#  'bad',
#  'film',
#  'a',
#  'visual',
#  'extravaganza',
#  '…',
#  'entertainment',
#  'guaranteed',
#  '.',
#  'The',
#  'scene',
#  'which',
#  'sees',
#  'Shiva',
#  'singlehandedly',
#  'erecting',
#  'a',
#  'giant',
#  'gold',
#  'statue',
#  'of',
#  'Bhallala',
#  'Deva',
#  'is',
#  'jawdroppingly',
#  'iconic',
#  '.',
#  'Take',
#  'a',
#  'bow',
#  'S.S.',
#  'Rajamouli',
#  '.']

# %%
len(tokens)
# Out:
# 271

# %%
doc
# Out:
# However, there are a few glitches, which may not be deal-breakers per say but do stick out. For instance, Tamannaah, who plays the Katniss Everdeen like bow-wielding warrior, breaks into a romantic song with Shiva, baring her slender midriff to cater to ‘popular demands’. Shiva’s impromptu dance under the waterfall is reminiscent of a Liril commercial. The film’s duration could be an issue for those not high on patience. Also, the movie reminds you of Troy, Thor, The Dark Knight Rises, Karan Arjun (Devasena chanting, ‘Mera beta aayega’) to name a few, giving you the recurring ‘been-there-seen-that’ feeling. Shiva has the values of Prince Hector, bravery of Achilles and can make the jump Bruce Wayne did to get out of the pit. Bhallala deva can be Agamemnon.However, the elaborate battle-scene climax makes the film a spectacular watch nonetheless. Very rarely has an Indian film managed to achieve this feat. The casting is terrific. Ramya Krishnan in her short but substantial role is flawless as the feisty Raajmata. Tamannaah does the action bit well. Prabhas and Rana Daggubati are outstanding. They hugely contribute to making this routine good vs bad film a visual extravaganza…entertainment guaranteed. The scene which sees Shiva singlehandedly erecting a giant gold statue of Bhallala Deva is jawdroppingly iconic. Take a bow S.S. Rajamouli.

# %%
# i find token score
word_frequencies ={}

for word in doc:
    if word.text.lower() not in stopwords:
        if word.text.lower() not in punctuation:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] =1
            else:
                word_frequencies[word.text]  +=1

# %%
word_frequencies
# Out:
# {'glitches': 1,
#  'deal': 1,
#  'breakers': 1,
#  'stick': 1,
#  'instance': 1,
#  'Tamannaah': 2,
#  'plays': 1,
#  'Katniss': 1,
#  'Everdeen': 1,
#  'like': 1,
#  'bow': 2,
#  'wielding': 1,
#  'warrior': 1,
#  'breaks': 1,
#  'romantic': 1,
#  'song': 1,
#  'Shiva': 4,
#  'baring': 1,
#  'slender': 1,
#  'midriff': 1,
#  'cater': 1,
#  '‘': 3,
#  'popular': 1,
#  'demands': 1,
#  '’': 3,
#  'impromptu': 1,
#  'dance': 1,
#  'waterfall': 1,
#  'reminiscent': 1,
#  'Liril': 1,
#  'commercial': 1,
#  'film': 4,
#  'duration': 1,
#  'issue': 1,
#  'high': 1,
#  'patience': 1,
#  'movie': 1,
#  'reminds': 1,
#  'Troy': 1,
#  'Thor': 1,
#  'Dark': 1,
#  'Knight': 1,
#  'Rises': 1,
#  'Karan': 1,
#  'Arjun': 1,
#  'Devasena': 1,
#  'chanting': 1,
#  'Mera': 1,
#  'beta': 1,
#  'aayega': 1,
#  'giving': 1,
#  'recurring': 1,
#  'seen': 1,
#  'feeling': 1,
#  'values': 1,
#  'Prince': 1,
#  'Hector': 1,
#  'bravery': 1,
#  'Achilles': 1,
#  'jump': 1,
#  'Bruce': 1,
#  'Wayne': 1,
#  'pit': 1,
#  'Bhallala': 2,
#  'deva': 1,
#  'Agamemnon': 1,
#  'elaborate': 1,
#  'battle': 1,
#  'scene': 2,
#  'climax': 1,
#  'makes': 1,
#  'spectacular': 1,
#  'watch': 1,
#  'nonetheless': 1,
#  'rarely': 1,
#  'Indian': 1,
#  'managed': 1,
#  'achieve': 1,
#  'feat': 1,
#  'casting': 1,
#  'terrific': 1,
#  'Ramya': 1,
#  'Krishnan': 1,
#  'short': 1,
#  'substantial': 1,
#  'role': 1,
#  'flawless': 1,
#  'feisty': 1,
#  'Raajmata': 1,
#  'action': 1,
#  'bit': 1,
#  'Prabhas': 1,
#  'Rana': 1,
#  'Daggubati': 1,
#  'outstanding': 1,
#  'hugely': 1,
#  'contribute': 1,
#  'making': 1,
#  'routine': 1,
#  'good': 1,
#  'vs': 1,
#  'bad': 1,
#  'visual': 1,
#  'extravaganza': 1,
#  '…': 1,
#  'entertainment': 1,
#  'guaranteed': 1,
#  'sees': 1,
#  'singlehandedly': 1,
#  'erecting': 1,
#  'giant': 1,
#  'gold': 1,
#  'statue': 1,
#  'Deva': 1,
#  'jawdroppingly': 1,
#  'iconic': 1,
#  'S.S.': 1,
#  'Rajamouli': 1}

# %%
len(word_frequencies)
# Out:
# 118

# %%
max_frequencies =max(word_frequencies.values())
max_frequencies
# Out:
# 4

# %%
# calculate Weighted token score
for word in word_frequencies.keys():
    word_frequencies[word] =word_frequencies[word]/max_frequencies

# %%
word_frequencies
# Out:
# {'glitches': 0.25,
#  'deal': 0.25,
#  'breakers': 0.25,
#  'stick': 0.25,
#  'instance': 0.25,
#  'Tamannaah': 0.5,
#  'plays': 0.25,
#  'Katniss': 0.25,
#  'Everdeen': 0.25,
#  'like': 0.25,
#  'bow': 0.5,
#  'wielding': 0.25,
#  'warrior': 0.25,
#  'breaks': 0.25,
#  'romantic': 0.25,
#  'song': 0.25,
#  'Shiva': 1.0,
#  'baring': 0.25,
#  'slender': 0.25,
#  'midriff': 0.25,
#  'cater': 0.25,
#  '‘': 0.75,
#  'popular': 0.25,
#  'demands': 0.25,
#  '’': 0.75,
#  'impromptu': 0.25,
#  'dance': 0.25,
#  'waterfall': 0.25,
#  'reminiscent': 0.25,
#  'Liril': 0.25,
#  'commercial': 0.25,
#  'film': 1.0,
#  'duration': 0.25,
#  'issue': 0.25,
#  'high': 0.25,
#  'patience': 0.25,
#  'movie': 0.25,
#  'reminds': 0.25,
#  'Troy': 0.25,
#  'Thor': 0.25,
#  'Dark': 0.25,
#  'Knight': 0.25,
#  'Rises': 0.25,
#  'Karan': 0.25,
#  'Arjun': 0.25,
#  'Devasena': 0.25,
#  'chanting': 0.25,
#  'Mera': 0.25,
#  'beta': 0.25,
#  'aayega': 0.25,
#  'giving': 0.25,
#  'recurring': 0.25,
#  'seen': 0.25,
#  'feeling': 0.25,
#  'values': 0.25,
#  'Prince': 0.25,
#  'Hector': 0.25,
#  'bravery': 0.25,
#  'Achilles': 0.25,
#  'jump': 0.25,
#  'Bruce': 0.25,
#  'Wayne': 0.25,
#  'pit': 0.25,
#  'Bhallala': 0.5,
#  'deva': 0.25,
#  'Agamemnon': 0.25,
#  'elaborate': 0.25,
#  'battle': 0.25,
#  'scene': 0.5,
#  'climax': 0.25,
#  'makes': 0.25,
#  'spectacular': 0.25,
#  'watch': 0.25,
#  'nonetheless': 0.25,
#  'rarely': 0.25,
#  'Indian': 0.25,
#  'managed': 0.25,
#  'achieve': 0.25,
#  'feat': 0.25,
#  'casting': 0.25,
#  'terrific': 0.25,
#  'Ramya': 0.25,
#  'Krishnan': 0.25,
#  'short': 0.25,
#  'substantial': 0.25,
#  'role': 0.25,
#  'flawless': 0.25,
#  'feisty': 0.25,
#  'Raajmata': 0.25,
#  'action': 0.25,
#  'bit': 0.25,
#  'Prabhas': 0.25,
#  'Rana': 0.25,
#  'Daggubati': 0.25,
#  'outstanding': 0.25,
#  'hugely': 0.25,
#  'contribute': 0.25,
#  'making': 0.25,
#  'routine': 0.25,
#  'good': 0.25,
#  'vs': 0.25,
#  'bad': 0.25,
#  'visual': 0.25,
#  'extravaganza': 0.25,
#  '…': 0.25,
#  'entertainment': 0.25,
#  'guaranteed': 0.25,
#  'sees': 0.25,
#  'singlehandedly': 0.25,
#  'erecting': 0.25,
#  'giant': 0.25,
#  'gold': 0.25,
#  'statue': 0.25,
#  'Deva': 0.25,
#  'jawdroppingly': 0.25,
#  'iconic': 0.25,
#  'S.S.': 0.25,
#  'Rajamouli': 0.25}

# %%
# convert para to sentance
sentence_tokens =[sent for sent in doc.sents]
sentence_tokens
# Out:
# [However, there are a few glitches, which may not be deal-breakers per say but do stick out.,
#  For instance, Tamannaah, who plays the Katniss Everdeen like bow-wielding warrior, breaks into a romantic song with Shiva, baring her slender midriff to cater to ‘popular demands’.,
#  Shiva’s impromptu dance under the waterfall is reminiscent of a Liril commercial.,
#  The film’s duration could be an issue for those not high on patience.,
#  Also, the movie reminds you of Troy, Thor, The Dark Knight Rises, Karan Arjun (Devasena chanting, ‘Mera beta aayega’) to name a few, giving you the recurring ‘been-there-seen-that’ feeling.,
#  Shiva has the values of Prince Hector, bravery of Achilles and can make the jump Bruce Wayne did to get out of the pit.,
#  Bhallala deva can be Agamemnon.,
#  However, the elaborate battle-scene climax makes the film a spectacular watch nonetheless.,
#  Very rarely has an Indian film managed to achieve this feat.,
#  The casting is terrific.,
#  Ramya Krishnan in her short but substantial role is flawless as the feisty Raajmata.,
#  Tamannaah does the action bit well.,
#  Prabhas and Rana Daggubati are outstanding.,
#  They hugely contribute to making this routine good vs bad film a visual extravaganza…entertainment guaranteed.,
#  The scene which sees Shiva singlehandedly erecting a giant gold statue of Bhallala Deva is jawdroppingly iconic.,
#  Take a bow S.S. Rajamouli.]

# %%
len(sentence_tokens)
# Out:
# 16

# %%
sentence_scores = {}

for sent in sentence_tokens:
    for word in sent:
        if word.text.lower() in word_frequencies.keys():
            if sent not in sentence_scores.keys():
                sentence_scores[sent] = word_frequencies[word.text.lower()]
            else:
                sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
sentence_scores
# Out:
# {However, there are a few glitches, which may not be deal-breakers per say but do stick out.: 1.0,
#  For instance, Tamannaah, who plays the Katniss Everdeen like bow-wielding warrior, breaks into a romantic song with Shiva, baring her slender midriff to cater to ‘popular demands’.: 5.5,
#  Shiva’s impromptu dance under the waterfall is reminiscent of a Liril commercial.: 1.25,
#  The film’s duration could be an issue for those not high on patience.: 2.0,
#  Also, the movie reminds you of Troy, Thor, The Dark Knight Rises, Karan Arjun (Devasena chanting, ‘Mera beta aayega’) to name a few, giving you the recurring ‘been-there-seen-that’ feeling.: 5.25,
#  Shiva has the values of Prince Hector, bravery of Achilles and can make the jump Bruce Wayne did to get out of the pit.: 1.0,
#  Bhallala deva can be Agamemnon.: 0.25,
#  However, the elaborate battle-scene climax makes the film a spectacular watch nonetheless.: 3.25,
#  Very rarely has an Indian film managed to achieve this feat.: 2.0,
#  The casting is terrific.: 0.5,
#  Ramya Krishnan in her short but substantial role is flawless as the feisty Raajmata.: 1.25,
#  Tamannaah does the action bit well.: 0.5,
#  Prabhas and Rana Daggubati are outstanding.: 0.25,
#  They hugely contribute to making this routine good vs bad film a visual extravaganza…entertainment guaranteed.: 4.0,
#  The scene which sees Shiva singlehandedly erecting a giant gold statue of Bhallala Deva is jawdroppingly iconic.: 2.75,
#  Take a bow S.S. Rajamouli.: 0.5}

# %%
len(sentence_scores)
# Out:
# 16

# %%
max_sentence_scores= max(sentence_scores.values())
max_sentence_scores
# Out:
# 5.5

# %%
from heapq import nlargest

# %%
select_length =int(len(sentence_tokens)*0.4)
select_length
# Out:
# 6

# %%
summary = nlargest(select_length,sentence_scores, key = sentence_scores.get)

# %%
summary
# Out:
# [For instance, Tamannaah, who plays the Katniss Everdeen like bow-wielding warrior, breaks into a romantic song with Shiva, baring her slender midriff to cater to ‘popular demands’.,
#  Also, the movie reminds you of Troy, Thor, The Dark Knight Rises, Karan Arjun (Devasena chanting, ‘Mera beta aayega’) to name a few, giving you the recurring ‘been-there-seen-that’ feeling.,
#  They hugely contribute to making this routine good vs bad film a visual extravaganza…entertainment guaranteed.,
#  However, the elaborate battle-scene climax makes the film a spectacular watch nonetheless.,
#  The scene which sees Shiva singlehandedly erecting a giant gold statue of Bhallala Deva is jawdroppingly iconic.,
#  The film’s duration could be an issue for those not high on patience.]

# %%
final_summary = [word.text for word in summary]

# %%
final_summary
# Out:
# ['For instance, Tamannaah, who plays the Katniss Everdeen like bow-wielding warrior, breaks into a romantic song with Shiva, baring her slender midriff to cater to ‘popular demands’.',
#  'Also, the movie reminds you of Troy, Thor, The Dark Knight Rises, Karan Arjun (Devasena chanting, ‘Mera beta aayega’) to name a few, giving you the recurring ‘been-there-seen-that’ feeling.',
#  'They hugely contribute to making this routine good vs bad film a visual extravaganza…entertainment guaranteed.',
#  'However, the elaborate battle-scene climax makes the film a spectacular watch nonetheless.',
#  'The scene which sees Shiva singlehandedly erecting a giant gold statue of Bhallala Deva is jawdroppingly iconic.',
#  'The film’s duration could be an issue for those not high on patience.']
