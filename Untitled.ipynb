# %%
import spacy
nlp =spacy.load('en_core_web_sm')
doc =nlp('The two-part Baahubali series (2015–2017) redefined Indian cinema’s scope, breaking box-office records and earning international recognition for its grand visual effects')

# %%
doc
# Out:
# The two-part Baahubali series (2015–2017) redefined Indian cinema’s scope, breaking box-office records and earning international recognition for its grand visual effects

# %%
for word in doc:
    print(word.text)
# Out:
# The
# two
# -
# part
# Baahubali
# series
# (
# 2015–2017
# )
# redefined
# Indian
# cinema
# ’s
# scope
# ,
# breaking
# box
# -
# office
# records
# and
# earning
# international
# recognition
# for
# its
# grand
# visual
# effects

# %%
for token in doc:
    print(token.text,token.pos_,token.lemma_,token.tag_,token.dep_,token.shape_,token.is_alpha,token.is_stop)
# Out:
# The DET the DT det Xxx True True
# two NUM two CD nummod xxx True True
# - PUNCT - HYPH punct - False False
# part NOUN part NN nmod xxxx True True
# Baahubali PROPN Baahubali NNP amod Xxxxx True False
# series NOUN series NN nsubj xxxx True False
# ( PUNCT ( -LRB- punct ( False False
# 2015–2017 NUM 2015–2017 CD appos dddd–dddd False False
# ) PUNCT ) -RRB- punct ) False False
# redefined VERB redefine VBD ROOT xxxx True False
# Indian ADJ indian JJ amod Xxxxx True False
# cinema PROPN cinema NNP nmod xxxx True False
# ’s PART ’s POS case ’x False True
# scope NOUN scope NN dobj xxxx True False
# , PUNCT , , punct , False False
# breaking VERB break VBG amod xxxx True False
# box NOUN box NN compound xxx True False
# - PUNCT - HYPH punct - False False
# office NOUN office NN compound xxxx True False
# records NOUN record NNS conj xxxx True False
# and CCONJ and CC cc xxx True True
# earning VERB earn VBG conj xxxx True False
# international ADJ international JJ amod xxxx True False
# ...

# %%
for token in doc:
    print(token.pos_)
# Out:
# DET
# NUM
# PUNCT
# NOUN
# PROPN
# NOUN
# PUNCT
# NUM
# PUNCT
# VERB
# ADJ
# PROPN
# PART
# NOUN
# PUNCT
# VERB
# NOUN
# PUNCT
# NOUN
# NOUN
# CCONJ
# VERB
# ADJ
# NOUN
# ADP
# PRON
# ADJ
# ADJ
# NOUN

# %%
for token in doc:
    print(token.text,token.pos_)
# Out:
# The DET
# two NUM
# - PUNCT
# part NOUN
# Baahubali PROPN
# series NOUN
# ( PUNCT
# 2015–2017 NUM
# ) PUNCT
# redefined VERB
# Indian ADJ
# cinema PROPN
# ’s PART
# scope NOUN
# , PUNCT
# breaking VERB
# box NOUN
# - PUNCT
# office NOUN
# records NOUN
# and CCONJ
# earning VERB
# international ADJ
# recognition NOUN
# for ADP
# its PRON
# grand ADJ
# visual ADJ
# effects NOUN

# %%
for token in doc:
    print(token.text,token.pos_,token.lemma_)
# Out:
# The DET the
# two NUM two
# - PUNCT -
# part NOUN part
# Baahubali PROPN Baahubali
# series NOUN series
# ( PUNCT (
# 2015–2017 NUM 2015–2017
# ) PUNCT )
# redefined VERB redefine
# Indian ADJ indian
# cinema PROPN cinema
# ’s PART ’s
# scope NOUN scope
# , PUNCT ,
# breaking VERB break
# box NOUN box
# - PUNCT -
# office NOUN office
# records NOUN record
# and CCONJ and
# earning VERB earn
# international ADJ international
# recognition NOUN recognition
# for ADP for
# its PRON its
# grand ADJ grand
# visual ADJ visual
# effects NOUN effect

# %%
text='Rajamouli was born into a Telugu family of storytellers—his father, screenwriter V. Vijayendra Prasad, later wrote blockbusters such as Bajrangi Bhaijaan. Growing up between Karnataka and Andhra Pradesh, he developed an early fascination with Indian epics like the Ramayana and Mahabharata. His childhood exposure to Amar Chitra Katha comics and mythological tales shaped his narrative style centered on heroism and moral conflict.

Career and cinematic vision
Beginning his career under veteran filmmaker K. Raghavendra Rao, Rajamouli made his directorial debut with Student No: 1 (2001). He gained success through action hits such as Simhadri (2003) and Vikramarkudu (2006) before achieving nationwide recognition with the fantasy film Magadheera (2009). His inventive revenge tale Eega (2012), featuring a housefly protagonist, demonstrated his mastery of CGI integration and earned two National Film Awards.

Pan-Indian success and global acclaim
The two-part Baahubali series (2015–2017) redefined Indian cinema’s scope, breaking box-office records and earning international recognition for its grand visual effects and mythic scale. His follow-up, RRR (2022), an epic about fictionalized Indian freedom fighters Alluri Sitarama Raju and Komaram Bheem, won a Golden Globe and an Oscar for Best Original Song (“Naatu Naatu”). Rajamouli also received the New York Film Critics Circle Award for Best Directo
# Out:
#   Cell In[9], line 1
#     text="""Rajamouli was born into a Telugu family of storytellers—his father, screenwriter V. Vijayendra Prasad, later wrote blockbusters such as Bajrangi Bhaijaan. Growing up between Karnataka and Andhra Pradesh, he developed an early fascination with Indian epics like the Ramayana and Mahabharata. His childhood exposure to Amar Chitra Katha comics and mythological tales shaped his narrative style centered on heroism and moral conflict.
#          ^
# _IncompleteInputError: incomplete input
